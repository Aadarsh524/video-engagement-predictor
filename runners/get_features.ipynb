# %%
# Week 2 Thursday: Testing Feature Module
import pandas as pd
import sys
sys.path.append('../src')

from features import create_all_features, get_feature_summary



# Load your data
df = pd.read_csv('../data/features/youtube_features.csv')


print(f"Original dataset: {df.shape}")

# Apply all features
df_with_features = create_all_features(
    df, 
    title_col='title',
)

# Get summary
get_feature_summary(df_with_features)

# Save processed features
df_with_features.to_csv('../data/features/features_complete.csv', index=False)
print("\n✅ Features saved to: data/features/features_complete.csv")
# Out:
# Original dataset: (55886, 24)
# Starting feature engineering pipeline...
# Feature engineering complete!
#
# Feature Summary:
# index: Type=int64, Missing=0
#    Mean=102265.98, Range=[0.00,161469.00]
# video_id: Type=object, Missing=0
# trending_date: Type=object, Missing=0
# channel_title: Type=object, Missing=0
# category_id: Type=int64, Missing=0
#    Mean=20.62, Range=[1.00,44.00]
# publish_date: Type=object, Missing=0
# time_frame: Type=object, Missing=0
# published_day_of_week: Type=object, Missing=0
# publish_country: Type=object, Missing=0
# tags: Type=object, Missing=0
# views: Type=int64, Missing=0
#    Mean=227699.81, Range=[274.00,1080586.00]
# likes: Type=int64, Missing=0
#    Mean=6402.01, Range=[0.00,30368.00]
# dislikes: Type=int64, Missing=0
#    Mean=227.66, Range=[0.00,1061.00]
# comment_count: Type=int64, Missing=0
#    Mean=881.63, Range=[0.00,4214.00]
# comments_disabled: Type=bool, Missing=0
# ratings_disabled: Type=bool, Missing=0
# video_error_or_removed: Type=bool, Missing=0
# category_name: Type=object, Missing=0
# is_published_weekend: Type=bool, Missing=0
# trending_day_of_week: Type=object, Missing=0
# is_trending_weekend: Type=bool, Missing=0
# hour_of_trending: Type=int64, Missing=0
#    Mean=14.19, Range=[0.00,23.00]
# days_until_trending: Type=int64, Missing=0
#    Mean=7.10, Range=[0.00,4215.00]
# title_length: Type=int64, Missing=0
#    Mean=60.12, Range=[1.00,280.00]
# uppercase_words: Type=int64, Missing=0
#    Mean=2.21, Range=[0.00,21.00]
# contains_numbers_or_emojis: Type=int64, Missing=0
#    Mean=0.58, Range=[0.00,1.00]
# num_emojis: Type=int64, Missing=0
#    Mean=0.47, Range=[0.00,61.00]
# has_emoji: Type=int64, Missing=0
#    Mean=0.24, Range=[0.00,1.00]
# sentiment_polarity: Type=float64, Missing=0
#    Mean=0.04, Range=[-1.00,1.00]
# sentiment_subjectivity: Type=float64, Missing=0
#    Mean=0.16, Range=[0.00,1.00]
# is_title_english: Type=bool, Missing=0
# top50_pca1: Type=float64, Missing=0
#    Mean=-0.00, Range=[-0.19,0.99]
# top50_pca2: Type=float64, Missing=0
#    Mean=0.00, Range=[-0.32,1.64]
# top50_pca3: Type=float64, Missing=0
#    Mean=-0.00, Range=[-0.10,1.36]
# published_day_of_week_num: Type=int64, Missing=0
#    Mean=2.94, Range=[0.00,6.00]
#
# ✅ Features saved to: data/features/features_complete.csv
