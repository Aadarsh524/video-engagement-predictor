# %%
import sys, os

# --- Safe project root setup (works in notebook & scripts) ---
if "__file__" in globals():
    current_dir = os.path.dirname(os.path.abspath(__file__))
else:
    current_dir = os.getcwd()
    
    

project_root = os.path.abspath(os.path.join(current_dir, ".."))

sys.path.append(os.path.join(project_root, "src"))

from eda_pipeline import EdaPipeline

# --- Define clean paths ---
raw_data_path = os.path.join(project_root, "data", "raw", "youtube.csv")
clean_data_path = os.path.join(project_root, "data", "processed", "youtube_cleaned.csv")

# --- Create output folders (if missing) ---
os.makedirs(os.path.join(project_root, "reports", "figures"), exist_ok=True)
os.makedirs(os.path.join(project_root, "reports", "eda"), exist_ok=True)

# --- Run pipeline ---
pipeline = EdaPipeline(clean_data_path, output_prefix="cleaned")
pipeline.run_pipeline()
pipeline.generate_report(preview_in_notebook=True) 

print("✅ EDA Pipeline completed successfully!")
# Out:
# 2025-11-12 00:25:40,187 - INFO - 🚀 Running EDA pipeline for cleaned data...
# 2025-11-12 00:25:40,232 - INFO - Basic info collected for cleaned
# 2025-11-12 00:25:40,232 - INFO - {'shape': (55886, 19), 'columns': ['index', 'video_id', 'trending_date', 'title', 'channel_title', 'category_id', 'publish_date', 'time_frame', 'published_day_of_week', 'publish_country', 'tags', 'views', 'likes', 'dislikes', 'comment_count', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed', 'category_name'], 'dtypes': {'index': 'int64', 'video_id': 'object', 'trending_date': 'object', 'title': 'object', 'channel_title': 'object', 'category_id': 'int64', 'publish_date': 'object', 'time_frame': 'object', 'published_day_of_week': 'object', 'publish_country': 'object', 'tags': 'object', 'views': 'int64', 'likes': 'int64', 'dislikes': 'int64', 'comment_count': 'int64', 'comments_disabled': 'bool', 'ratings_disabled': 'bool', 'video_error_or_removed': 'bool', 'category_name': 'object'}, 'missing_count': {'index': 0, 'video_id': 0, 'trending_date': 0, 'title': 0, 'channel_title': 0, 'category_id': 0, 'publish_date': 0, 'time_frame': 0, 'published_day_of_week': 0, 'publish_country': 0, 'tags': 0, 'views': 0, 'likes': 0, 'dislikes': 0, 'comment_count': 0, 'comments_disabled': 0, 'ratings_disabled': 0, 'video_error_or_removed': 0, 'category_name': 0}, 'memory_usage_MB': np.float64(57.167)}
# 2025-11-12 00:25:40,881 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Histogram.png
# 💡 Insight: All metrics show right-skewed distributions on log scale,
#    indicating most videos have moderate engagement with few viral outliers.
# 2025-11-12 00:25:41,411 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Box.png
# 💡 Insight: All metrics show right-skewed distributions on log scale,
#    indicating most videos have moderate engagement with few viral outliers.
# 2025-11-12 00:25:42,449 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Density.png
# 2025-11-12 00:25:42,464 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:42,466 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:42,467 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:42,468 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:42,469 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:42,471 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:42,472 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:42,473 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-12 00:25:43,395 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Temporal.png
# 2025-11-12 00:25:43,414 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# /Users/aadarshghimire/Desktop/video-engagement-predictor/src/eda_pipeline.py:141: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x='published_day_of_week', y='views', order=day_order, palette='Set2')
# 2025-11-12 00:25:43,429 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 💡 Insight: Monthly trends show how engagement metrics evolved over time.
#    Look for seasonal patterns or overall growth/decline trends.
# 2025-11-12 00:25:43,748 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Weekly.png
# 2025-11-12 00:25:43,959 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Day_Average.png
# 💡 Insight: Analyze which day shows highest average views.
#    Best day: Saturday with 237,400 avg views
# 2025-11-12 00:25:45,482 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Categorical.png
# 2025-11-12 00:25:45,641 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Heatmap.png
# === TOP CATEGORIES BY AVERAGE VIEWS ===
# Shows: 500,671 avg views
# Music: 348,230 avg views
# Science & Technology: 303,959 avg views
# Comedy: 293,211 avg views
# Entertainment: 252,197 avg views
#
# 💡 Insight: High correlations between views and other metrics suggest
#    that videos with more views tend to get proportionally more engagement.
#
# Correlation with Views:
#   - Likes: 0.764
#   - Dislikes: 0.857
#   - Comment_count: 0.736
#
# === OUTLIER STATISTICS ===
# Total outliers: 5985 (10.71%)
# Lower bound: -371,117 views
# Upper bound: 684,667 views
# 2025-11-12 00:25:46,556 - INFO - 📊 Saved figure: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/figures/cleaned/Scatter.png
# 2025-11-12 00:25:46,636 - INFO - ✅ Text summary report saved at /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/eda/cleaned_eda_summary.txt
# === VIEWS PERCENTILE ANALYSIS ===
# 50th Percentile: 97,096 views
# 75th Percentile: 288,748 views
# 90th Percentile: 723,184 views
# 95th Percentile: 1,080,586 views
# 99th Percentile: 1,080,586 views
# 99.9th Percentile: 1,080,586 views
#
# === OUTLIER CHARACTERISTICS ===
# Mean views (all videos): 227,700
# Mean views (outliers): 979,000
# Median views (all videos): 97,096
# Median views (outliers): 1,080,586
#
# === TOP CATEGORIES FOR VIRAL VIDEOS ===
# category_name
# Entertainment           1749
# Music                    927
# Sports                   711
# Comedy                   666
# People & Blogs           482
# Howto & Style            313
# Film & Animation         310
# News & Politics          263
# Science & Technology     204
# Gaming                   204
# Name: count, dtype: int64
# 2025-11-12 00:25:50,713 - INFO - 📘 PDF Report saved: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/eda/cleaned_eda_report.pdf
# 2025-11-12 00:25:50,714 - INFO - ✅ EDA pipeline complete for cleaned
# 2025-11-12 00:25:54,696 - INFO - 📘 PDF Report saved: /Users/aadarshghimire/Desktop/video-engagement-predictor/reports/eda/cleaned_eda_report.pdf
#         <iframe
#             width="800"
#             height="600"
#             src="/Users/aadarshghimire/Desktop/video-engagement-predictor/reports/eda/cleaned_eda_report.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ✅ EDA Pipeline completed successfully!
